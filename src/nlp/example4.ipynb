# %%
import nltk.book as book
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
# Print random text, generated using a trigram language model.
book.text1.generate()
# Out:
# Building ngram index...
# long , from one to the top - mast , and no coffin and went out a sea
# captain -- this peaking of the whales . , so as to preserve all his
# might had in former years abounding with them , they toil with their
# lances , strange tales of Southern whaling . at once the bravest
# Indians he was , after in vain strove to pierce the profundity . ?
# then ?" a levelled flame of pale , And give no chance , watch him ;
# though the line , it is to be gainsaid . have been
# 'long , from one to the top - mast , and no coffin and went out a sea\ncaptain -- this peaking of the whales . , so as to preserve all his\nmight had in former years abounding with them , they toil with their\nlances , strange tales of Southern whaling . at once the bravest\nIndians he was , after in vain strove to pierce the profundity . ?\nthen ?" a levelled flame of pale , And give no chance , watch him ;\nthough the line , it is to be gainsaid . have been'

# %%
book.text2.generate()
# Out:
# Building ngram index...
# knew , had by this remembrance , and if , by rapid degrees , so long .
# , she could live without one another , and in her rambles . at least
# the last evening of a brother , could you know , from the first .
# Dashwood ? this gentleman himself , and must put up with a kindness
# which they are very much vexed at , for it -- and I shall keep it
# entirely . admire it ; and it is , explain the grounds , or if any
# place could give her ease , was a
# 'knew , had by this remembrance , and if , by rapid degrees , so long .\n, she could live without one another , and in her rambles . at least\nthe last evening of a brother , could you know , from the first .\nDashwood ? this gentleman himself , and must put up with a kindness\nwhich they are very much vexed at , for it -- and I shall keep it\nentirely . admire it ; and it is , explain the grounds , or if any\nplace could give her ease , was a'

# %%
book.text3.generate()
# Out:
# Building ngram index...
# laid by her , and said unto Cain , Where art thou , and said , Go to ,
# I will not do it for ten ' s sons ; we dreamed each man according to
# their generatio the firstborn said unto Laban , Because I said , Nay ,
# but Sarah shall her name be . , duke Elah , duke Shobal , and Akan .
# and looked upon my affliction . Bashemath Ishmael ' s blood , but Isra
# for as a prince hast thou found of all the cattle in the valley , and
# the wo The
# "laid by her , and said unto Cain , Where art thou , and said , Go to ,\nI will not do it for ten ' s sons ; we dreamed each man according to\ntheir generatio the firstborn said unto Laban , Because I said , Nay ,\nbut Sarah shall her name be . , duke Elah , duke Shobal , and Akan .\nand looked upon my affliction . Bashemath Ishmael ' s blood , but Isra\nfor as a prince hast thou found of all the cattle in the valley , and\nthe wo The"

# %%
book.text5.generate()
# Out:
# Building ngram index...
# he 's a good one is pathetic , just finish yout whereabouts no I had
# no choice but to let the kid out ! , me , hate to tell us she was
# innocent promise ? PART at least 3 girls per day please come on then
# you mean lucifer hi U120 PART :P hi U7 LOl U62 ... PART im so addicted
# to her beuty touch U101 , I forgot how many LIX DOES it take for a
# quarrel , turn your back itches and you pull out a case up rum soaked
# pineapples * this morning PART PART
# "he 's a good one is pathetic , just finish yout whereabouts no I had\nno choice but to let the kid out ! , me , hate to tell us she was\ninnocent promise ? PART at least 3 girls per day please come on then\nyou mean lucifer hi U120 PART :P hi U7 LOl U62 ... PART im so addicted\nto her beuty touch U101 , I forgot how many LIX DOES it take for a\nquarrel , turn your back itches and you pull out a case up rum soaked\npineapples * this morning PART PART"

# %%
# get the full length of a given corpus (number of words and punctuation symbols which are known as "tokens")
len(book.text5)
# Out:
# 45010

# %%
# Now, instead of counting all the tokens of a corpus (duplicates are counted as well), let's see how many distinct tokens are there in the same corpus?
sorted(set(book.text5))
# Out:
# ['',
#  '!',
#  '!!',
#  '!!!',
#  '!!!!',
#  '!!!!!',
#  '!!!!!!',
#  '!!!!!!!',
#  '!!!!!!!!',
#  '!!!!!!!!!',
#  '!!!!!!!!!!',
#  '!!!!!!!!!!!',
#  '!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!',
#  '!!!!!!.',
#  '!!!!!.',
#  '!!!!....',
#  '!!!.',
#  '!!.',
#  '!!...',
#  '!.',
#  '!...',
#  '!=',
#  '!?',
#  '!??',
#  '!???',
#  '"',
#  '"...',
#  '"?',
#  '"s',
#  '#',
#  '###',
#  '####',
#  '#14-19teens',
#  '#40sPlus',
#  '#prideIsland',
#  '#prideisland',
#  '#talkcity-20s',
#  '#talkcity_adults',
#  '$',
#  '$$',
#  '$27',
#  '&',
#  '&^',
#  "'",
#  "''",
#  "'.",
#  "'d",
#  "'ello",
#  "'ll",
#  "'m",
#  "'n'",
#  "'re",
#  "'s",
#  "'ve",
#  '(',
#  '( o Y o )',
#  '(((',
#  '((((',
#  '(((((',
#  '((((((',
#  '(((((((',
#  '((((((((',
#  '(((((((((',
#  '((((((((((',
#  '(((((((((((',
# ...

# %%
# now let's count them
len(set(book.text5))
# Out:
# 6066

# %%
# Now let's calculate the lexical richness of out corpus:
len(set(book.text5)) / len(book.text5)
# Out:
# 0.13477005109975562

# %% [markdown]
# Only 13% of tokens are unique.

# %%
# How many times a word has occurred in a corpus
book.text3.count("smote")
# Out:
# 5

# %%
# What percentage of a text is taken by a specific word?
100 * book.text4.count('a') / len(book.text4)
# Out:
# 1.4569256756756757

# %%
book.text5.count("lol")
# Out:
# 704

# %%
100 * book.text5.count("lol") / len(book.text5)
# Out:
# 1.5640968673628082

# %% [markdown]
# Let's define functions for a few of the tasks we have done so far.

# %%
def lexical_diversity(text):
    return len(set(text)) / len(text)


def percentage(count, total):
    return 100 * count / total

# %%
lexical_diversity(book.text3)
# Out:
# 0.06230453042623537

# %%
lexical_diversity(book.text5)
# Out:
# 0.13477005109975562

# %%
percentage(4, 5)
# Out:
# 80.0

# %%
percentage(book.text4.count('a'), len(book.text4))
# Out:
# 1.4569256756756757
